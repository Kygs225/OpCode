# %% [markdown]
# <a href="https://colab.research.google.com/github/Kygs225/OpCode/blob/main/Guessnumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Bonjour Gomycode")
# Out:
# Bonjour Gomycode
